# %%
import os

from getpass import getpass
import nest_asyncio

from dotenv import load_dotenv

nest_asyncio.apply()

load_dotenv()
# Out:
# True

# %% [markdown]
# When building an LLM-based application, one of the first decisions you make is which LLM(s) to use (of course, you can use more than one if you wish).
#
# The LLM will be used at various stages of your pipeline, including
#
# - During indexing:
#   - 👩🏽‍⚖️ To judge data relevance (to index or not).
#   - 📖 Summarize data & index those summaries.
#
# - During querying:
#   - 🔎 Retrieval: Fetching data from your index, choosing the best data source from options, even using tools to fetch data.
#
#   - 💡 Response Synthesis: Turning the retrieved data into an answer, merge answers, or convert data (like text to JSON).
#
# LlamaIndex gives you a single interface to various LLMs. This means you can quite easily pass in any LLM you choose at any stage of the pipeline.
#
# In this course we'll primiarly use OpenAI. You can see a full list of LLM integrations [here](https://docs.llamaindex.ai/en/stable/module_guides/models/llms/modules.html) and use your LLM provider of choice.

# %%
from llama_index.llms.cohere import Cohere

llm = Cohere(model="command-r-plus", temperature=0.2)

response = llm.complete("Alexander the Great was a")

print(response)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[27], line 5
#       1 from llama_index.llms.cohere import Cohere
#       3 llm = Cohere(model="command-r-plus", temperature=0.2)
# ----> 5 response = llm.complete("Alexander the Great was a")
#       7 print(response)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/core/instrumentation/dispatcher.py:260, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     252 self.span_enter(
#     253     id_=id_,
#     254     bound_args=bound_args,
#    (...)    257     tags=tags,
#     258 )
#     259 try:
# --> 260     result = func(*args, **kwargs)
#     261 except BaseException as e:
#     262     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/core/llms/callbacks.py:429, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#     420 event_id = callback_manager.on_event_start(
#     421     CBEventType.LLM,
#     422     payload={
#    (...)    426     },
#     427 )
#     428 try:
# --> 429     f_return_val = f(_self, *args, **kwargs)
#     430 except BaseException as e:
#     431     callback_manager.on_event_end(
#     432         CBEventType.LLM,
#     433         payload={EventPayload.EXCEPTION: e},
#     434         event_id=event_id,
#     435     )
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/llms/cohere/base.py:174, in Cohere.complete(self, prompt, formatted, **kwargs)
#     168 if "stream" in all_kwargs:
#     169     warnings.warn(
#     170         "Parameter `stream` is not supported by the `chat` method."
#     171         "Use the `stream_chat` method instead"
#     172     )
# --> 174 response = completion_with_retry(
#     175     client=self._client,
#     176     max_retries=self.max_retries,
#     177     chat=False,
#     178     prompt=prompt,
#     179     **all_kwargs,
#     180 )
#     182 return CompletionResponse(
#     183     text=response.generations[0].text,
#     184     raw=response.__dict__,
#     185 )
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/llms/cohere/utils.py:177, in completion_with_retry(client, max_retries, chat, **kwargs)
#     174         else:
#     175             return client.generate(**kwargs)
# --> 177 return _completion_with_retry(**kwargs)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/tenacity/__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/tenacity/__init__.py:398, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     396 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398         self._add_action_func(lambda rs: rs.outcome.result())
#     399         return
#     401     if self.after is not None:
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/llms/cohere/utils.py:175, in completion_with_retry.<locals>._completion_with_retry(**kwargs)
#     173     return client.generate_stream(**kwargs)
#     174 else:
# --> 175     return client.generate(**kwargs)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/cohere/base_client.py:1018, in BaseCohere.generate(self, prompt, model, num_generations, max_tokens, truncate, temperature, seed, preset, end_sequences, stop_sequences, k, p, frequency_penalty, presence_penalty, return_likelihoods, raw_prompting, request_options)
#     893 def generate(
#     894     self,
#     895     *,
#    (...)    912     request_options: typing.Optional[RequestOptions] = None,
#     913 ) -> Generation:
#     914     """
#     915     <Warning>
#     916     This API is marked as "Legacy" and is no longer maintained. Follow the [migration guide](https://docs.cohere.com/docs/migrating-from-cogenerate-to-cochat) to start using the Chat API.
#    (...)   1016     )
#    1017     """
# -> 1018     _response = self._raw_client.generate(
#    1019         prompt=prompt,
#    1020         model=model,
#    1021         num_generations=num_generations,
#    1022         max_tokens=max_tokens,
#    1023         truncate=truncate,
#    1024         temperature=temperature,
#    1025         seed=seed,
#    1026         preset=preset,
#    1027         end_sequences=end_sequences,
#    1028         stop_sequences=stop_sequences,
#    1029         k=k,
#    1030         p=p,
#    1031         frequency_penalty=frequency_penalty,
#    1032         presence_penalty=presence_penalty,
#    1033         return_likelihoods=return_likelihoods,
#    1034         raw_prompting=raw_prompting,
#    1035         request_options=request_options,
#    1036     )
#    1037     return _response.data
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/cohere/raw_base_client.py:1479, in RawBaseCohere.generate(self, prompt, model, num_generations, max_tokens, truncate, temperature, seed, preset, end_sequences, stop_sequences, k, p, frequency_penalty, presence_penalty, return_likelihoods, raw_prompting, request_options)
#    1468     raise ForbiddenError(
#    1469         headers=dict(_response.headers),
#    1470         body=typing.cast(
#    (...)   1476         ),
#    1477     )
#    1478 if _response.status_code == 404:
# -> 1479     raise NotFoundError(
#    1480         headers=dict(_response.headers),
#    1481         body=typing.cast(
#    1482             typing.Optional[typing.Any],
#    1483             construct_type(
#    1484                 type_=typing.Optional[typing.Any],  # type: ignore
#    1485                 object_=_response.json(),
#    1486             ),
#    1487         ),
#    1488     )
#    1489 if _response.status_code == 422:
#    1490     raise UnprocessableEntityError(
#    1491         headers=dict(_response.headers),
#    1492         body=typing.cast(
#    (...)   1498         ),
#    1499     )
#
# NotFoundError: headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '223dd7a7c5198193f7ce12f321865ef3', 'x-endpoint-monthly-call-limit': '1000', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '39', 'date': 'Sun, 02 Nov 2025 12:00:07 GMT', 'x-envoy-upstream-service-time': '47', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 404, body: {'id': 'cbd5ee67-bf0c-4b85-9e3b-a6b2b42a0c4f', 'message': 'Generate API was removed on September 15 2025. Please migrate to Chat API. See https://docs.cohere.com/docs/migrating-from-cogenerate-to-cochat for details.'}

# %%
from llama_index.core import PromptTemplate

template = """Write a song about {thing} in the style of {style}."""

prompt = template.format(thing="a broken xylophone", style="parody rap") 

response = llm.complete(prompt)

print(response)

# %%
from llama_index.core.llms import ChatMessage
from llama_index.llms.cohere import Cohere

llm = Cohere(model="command-a-03-2025")

messages = [
    ChatMessage(role="system", content="You're a hella punk bot from South Sacramento"),
    ChatMessage(role="user", content="Hey, what's up dude."),
]

response = llm.chat(messages)

print(response)

# %%
from llama_index.core.llms import ChatMessage, MessageRole
from llama_index.core import ChatPromptTemplate
print(CO_API_KEY)
llm = Cohere(model="command-r-plus")

chat_template = [
    ChatMessage(role=MessageRole.SYSTEM,content="You always answers questions with as much detail as possible."),
    ChatMessage(role=MessageRole.USER, content="{question}")
    ]

chat_prompt = ChatPromptTemplate(chat_template)

response = llm.complete(chat_prompt.format(question="How far did Alexander the Great go in his conquests?"))

print(response)

# %%
from llama_index.llms.cohere import Cohere
from llama_index.core.llms import ChatMessage, MessageRole

llm = Cohere(model="command-r-plus")

messages = [
    ChatMessage(role=MessageRole.SYSTEM, content="You're a great historian bot."),
    ChatMessage(role=MessageRole.USER, content="When did Alexander the Great arrive in China?")
]

response = llm.stream_chat(messages)

for r in response:
    print(r.delta, end="")

# %%
from llama_index.core.chat_engine import SimpleChatEngine

llm = Cohere(model="command-r-plus")

chat_engine = SimpleChatEngine.from_defaults(llm=llm)

chat_engine.chat_repl()
