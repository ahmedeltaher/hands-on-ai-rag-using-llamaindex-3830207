# %%
# %%capture
# !pip install llama-index==0.10.37 llama-index-embeddings-openai==0.1.9 qdrant-client==1.9.1 llama-index-vector-stores-qdrant==0.2.8 llama-index-llms-cohere==0.2.0

# %%
# %%capture
# !pip install llama-index-llms-ollama llama-index-embeddings-cohere
# Out:
# Requirement already satisfied: llama-index-llms-ollama in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (0.9.0)
# Requirement already satisfied: llama-index-embeddings-cohere in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (0.6.1)
# Requirement already satisfied: llama-index-core<0.15,>=0.14.5 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-llms-ollama) (0.14.7)
# Requirement already satisfied: ollama>=0.5.1 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-llms-ollama) (0.6.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.13.1)
# Requirement already satisfied: aiosqlite in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.2.0)
# Requirement already satisfied: dataclasses-json in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2025.9.0)
# Requirement already satisfied: httpx in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.28.1)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.8.3)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.5)
# Requirement already satisfied: nltk>3.8.1 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.9.2)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.3.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (12.0.0)
# Requirement already satisfied: platformdirs in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (4.3.7)
# Requirement already satisfied: pydantic>=2.8.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.12.3)
# Requirement already satisfied: pyyaml>=6.0.1 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.32.5)
# Requirement already satisfied: setuptools>=80.9.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.0.44)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (8.5.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.12.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.9.0)
# Requirement already satisfied: wrapt in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.22.0)
# Requirement already satisfied: griffe in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.14.0)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.4.2)
# Requirement already satisfied: idna>=2.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.7)
# Requirement already satisfied: cohere<6,>=5.15 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from llama-index-embeddings-cohere) (5.20.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from cohere<6,>=5.15->llama-index-embeddings-cohere) (1.12.1)
# Requirement already satisfied: httpx-sse==0.4.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from cohere<6,>=5.15->llama-index-embeddings-cohere) (0.4.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from cohere<6,>=5.15->llama-index-embeddings-cohere) (2.41.4)
# Requirement already satisfied: tokenizers<1,>=0.15 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from cohere<6,>=5.15->llama-index-embeddings-cohere) (0.22.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from cohere<6,>=5.15->llama-index-embeddings-cohere) (2.32.4.20250913)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2025.10.5)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from tokenizers<1,>=0.15->cohere<6,>=5.15->llama-index-embeddings-cohere) (0.36.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6,>=5.15->llama-index-embeddings-cohere) (3.20.0)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6,>=5.15->llama-index-embeddings-cohere) (25.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6,>=5.15->llama-index-embeddings-cohere) (1.2.0)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from httpx->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from httpx->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.16.0)
# Requirement already satisfied: click in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (8.2.1)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2025.10.23)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.4.2)
# Requirement already satisfied: greenlet>=1 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from anyio->httpx->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.3.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from dataclasses-json->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.26.1)
# Requirement already satisfied: colorama>=0.4 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.0.2)

# %%
import os
from dotenv import load_dotenv
from getpass import getpass

import nest_asyncio

nest_asyncio.apply()
load_dotenv()
# Out:
# True

# %%
CO_API_KEY = os.environ['CO_API_KEY'] or getpass("Enter your Cohere API key: ")

# %%
OPENAI_API_KEY = os.environ['OPENAI_API_KEY'] or getpass("Enter your OpenAI API key: ")

# %%
QDRANT_URL = os.environ['QDRANT_URL'] or getpass("Enter your Qdrant URL:")

# %%
QDRANT_API_KEY = os.environ['QDRANT_API_KEY'] or  getpass("Enter your Qdrant API Key:")

# %%
from llama_index.core.settings import Settings
from llama_index.llms.cohere import Cohere
from llama_index.embeddings.cohere import CohereEmbedding
from llama_index.llms.ollama import Ollama

Settings.llm = Ollama(
    model="qwen2.5:7b",
    request_timeout=120.0,
    context_window=8000,
)

Settings.embed_model = CohereEmbedding(
    api_key=CO_API_KEY,
    model_name="embed-english-v3.0"
)

# %% [markdown]
# # Ingestion Pipeline
#
# - 🔄 **IngestionPipeline Overview**: Utilizes `Transformations` applied to input data, modifying data into nodes, which are returned or inserted to a vector database.
#
# - 💾 **Caching Mechanism**: Each node+transformation pair is cached, enhancing efficiency for identical subsequent operations by utilizing cached results.
#
#
# ### Using an `IngestionPipeline`
#
# First, let's read in some data.

# %%
from llama_index.core import SimpleDirectoryReader

documents = SimpleDirectoryReader(
    input_files = ["../02_Fundamental_Concepts_in_LlamaIndex/data/pg10763.txt"], 
    filename_as_id=True).load_data()

# %% [markdown]
# # Ingestion Pipeline with Document Management
#
#
#  •  💾 **Caching in IngestionPipeline**: Hashes and stores each node + transformation combination to speed up future processes with identical data.
#
#  •  📁 **Local Cache Management**: The input nodes list and transformation pair are cached in the pipeline. When we apply the same transformation to that list of nodes again, the output nodes are retrieved from the cache.
#
#  •  📚 **Docstore Attachment**:  Enables document management in the ingestion pipeline, using `doc_id` or `node.ref_doc_id` for identification. Prevents running a transformation on the same document multiple times by using the document ID and the hash of the document content to manage duplicates.
#
#  •  🗂️ **Duplicate Handling**:
#   - Maintains a `doc_id` to `document_hash` map to identify duplicates.
#
#   - Re-processes documents if the same `doc_id` is found with a changed hash.
#
#   - Skips documents if the same `doc_id` is found but the hash remains unchanged.
#
#  •  🚫 **Without Vector Store**:
#   - Limited to checking and removing duplicate inputs.
#
#  •  ✨ **With Vector Store**:
#   - Enables handling of upserts for updated documents, offering advanced management capabilities.

# %%
from qdrant_client import QdrantClient

from llama_index.core import StorageContext, VectorStoreIndex
from llama_index.core.ingestion import IngestionCache, IngestionPipeline
from llama_index.core.node_parser import TokenTextSplitter
from llama_index.core.storage.docstore import SimpleDocumentStore
from llama_index.vector_stores.qdrant import QdrantVectorStore

client = QdrantClient(
    url=QDRANT_URL, 
    api_key=QDRANT_API_KEY,
)

vector_store = QdrantVectorStore(
    client=client, 
    collection_name="it_can_be_done")

ingest_cache = IngestionCache(
    collection="it_can_be_done",
)

# create pipeline with transformations
pipeline = IngestionPipeline(
    transformations=[
        TokenTextSplitter(chunk_size=256, chunk_overlap=16),
        Settings.embed_model
    ],
    docstore=SimpleDocumentStore(),
    vector_store=vector_store,
    cache=ingest_cache,
)

# run the pipeline
nodes = pipeline.run(documents = documents)
# Out:
# 2025-11-03 10:29:50,906 - INFO - HTTP Request: GET https://7543de8f-e755-49ec-83ee-43eb16524b58.eu-central-1-0.aws.cloud.qdrant.io:6333 "HTTP/1.1 200 OK"
# 2025-11-03 10:29:51,007 - INFO - HTTP Request: GET https://7543de8f-e755-49ec-83ee-43eb16524b58.eu-central-1-0.aws.cloud.qdrant.io:6333/collections/it_can_be_done/exists "HTTP/1.1 200 OK"
# 2025-11-03 10:29:51,029 - INFO - HTTP Request: GET https://7543de8f-e755-49ec-83ee-43eb16524b58.eu-central-1-0.aws.cloud.qdrant.io:6333/collections/it_can_be_done "HTTP/1.1 200 OK"
# 2025-11-03 10:29:52,313 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:52,765 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:53,010 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:53,290 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:53,529 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:53,815 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:54,048 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:54,338 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:54,592 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:54,863 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:55,135 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:55,388 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:55,621 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:55,912 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:56,154 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:56,433 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:56,691 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:56,965 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:57,225 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:57,483 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:57,746 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:58,008 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:58,261 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:58,531 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:58,791 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:59,058 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:59,305 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:59,581 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:29:59,822 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:00,104 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:00,347 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:00,629 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:00,891 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:01,154 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:01,422 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:01,692 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:01,928 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:02,203 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:02,456 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:02,725 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:02,990 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:03,250 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:03,507 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:03,775 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:04,042 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:04,302 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:04,556 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:04,824 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:05,069 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:30:05,717 - INFO - HTTP Request: PUT https://7543de8f-e755-49ec-83ee-43eb16524b58.eu-central-1-0.aws.cloud.qdrant.io:6333/collections/it_can_be_done/points?wait=true "HTTP/1.1 200 OK"
# 2025-11-03 10:30:06,147 - INFO - HTTP Request: PUT https://7543de8f-e755-49ec-83ee-43eb16524b58.eu-central-1-0.aws.cloud.qdrant.io:6333/collections/it_can_be_done/points?wait=true "HTTP/1.1 200 OK"
# 2025-11-03 10:30:06,465 - INFO - HTTP Request: PUT https://7543de8f-e755-49ec-83ee-43eb16524b58.eu-central-1-0.aws.cloud.qdrant.io:6333/collections/it_can_be_done/points?wait=true "HTTP/1.1 200 OK"
# 2025-11-03 10:30:06,717 - INFO - HTTP Request: PUT https://7543de8f-e755-49ec-83ee-43eb16524b58.eu-central-1-0.aws.cloud.qdrant.io:6333/collections/it_can_be_done/points?wait=true "HTTP/1.1 200 OK"
# 2025-11-03 10:30:07,049 - INFO - HTTP Request: PUT https://7543de8f-e755-49ec-83ee-43eb16524b58.eu-central-1-0.aws.cloud.qdrant.io:6333/collections/it_can_be_done/points?wait=true "HTTP/1.1 200 OK"
# 2025-11-03 10:30:07,323 - INFO - HTTP Request: PUT https://7543de8f-e755-49ec-83ee-43eb16524b58.eu-central-1-0.aws.cloud.qdrant.io:6333/collections/it_can_be_done/points?wait=true "HTTP/1.1 200 OK"
# 2025-11-03 10:30:07,639 - INFO - HTTP Request: PUT https://7543de8f-e755-49ec-83ee-43eb16524b58.eu-central-1-0.aws.cloud.qdrant.io:6333/collections/it_can_be_done/points?wait=true "HTTP/1.1 200 OK"
# 2025-11-03 10:30:07,809 - INFO - HTTP Request: PUT https://7543de8f-e755-49ec-83ee-43eb16524b58.eu-central-1-0.aws.cloud.qdrant.io:6333/collections/it_can_be_done/points?wait=true "HTTP/1.1 200 OK"

# %%
nodes[0].__dict__.keys()
# Out:
# dict_keys(['id_', 'embedding', 'metadata', 'excluded_embed_metadata_keys', 'excluded_llm_metadata_keys', 'relationships', 'metadata_template', 'metadata_separator', 'text', 'mimetype', 'start_char_idx', 'end_char_idx', 'metadata_seperator', 'text_template'])

# %%
index = VectorStoreIndex.from_vector_store(vector_store=vector_store)

# %%
retriever = index.as_retriever(
    similarity_top_k=7, 
    return_sources=True
    )

# %%
retrieved_nodes = retriever.retrieve("Poems about starting where you stand, and not making dreams your master")
# Out:
# 2025-11-03 10:32:01,466 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2025-11-03 10:32:01,599 - INFO - HTTP Request: POST https://7543de8f-e755-49ec-83ee-43eb16524b58.eu-central-1-0.aws.cloud.qdrant.io:6333/collections/it_can_be_done/points/search "HTTP/1.1 200 OK"

# %%
retrieved_nodes
# Out:
# [NodeWithScore(node=TextNode(id_='d2129cd3-98bf-4fcd-b26d-44fea60f8e07', embedding=None, metadata={'file_path': '../02_Fundamental_Concepts_in_LlamaIndex/data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='../02_Fundamental_Concepts_in_LlamaIndex/data/pg10763.txt', node_type='4', metadata={'file_path': '../02_Fundamental_Concepts_in_LlamaIndex/data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, hash='255d600c24bf964367328bfeb213a0e5ed4983b8fdf2df1ea0385bf471f4ef84'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='2ebb66fb-2118-4eef-868d-6c5cdf235c69', node_type='1', metadata={'file_path': '../02_Fundamental_Concepts_in_LlamaIndex/data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, hash='9b059278ca6a05cd1924149332dcf18453f913167a7cf13ce13c32ed4d6e5025'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='c68c5d58-6872-4914-8d3f-6da3e7e7c2cb', node_type='1', metadata={}, hash='64e2a70442e8c469e26af6eeb7d971e07576325ca93a5b5e16c680dc1db2e206')}, metadata_template='{key}: {value}', metadata_separator='\n', text='the right way."\r\n\r\n  Then shall I see it not too great, nor small\r\n    To suit my spirit and to prove my powers;\r\n    Then shall I cheerful greet the laboring hours,\r\n  And cheerful turn, when the long shadows fall\r\n  At eventide, to play and love and rest,\r\n  Because I know for me my work is best.\r\n\r\n\r\n_Henry Van Dyke._\r\n\r\nFrom "Collected Poems."\r\n\r\n\r\n\r\n\r\nSTART WHERE YOU STAND\r\n\r\n\r\nWhen a man who had been in the penitentiary applied to Henry Ford for\r\nemployment, he started to tell Mr. Ford his story. "Never mind," said\r\nMr. Ford, "I don\'t care about the past. Start where you stand!"--Author\'s\r\nnote.\r\n\r\n\r\n  Start where you stand and never mind the past,\r\n    The past won\'t help you in beginning new,\r\n  If you have left it all behind at last\r\n    Why, that\'s enough, you\'re done with it, you\'re through;\r\n  This is another chapter in the book,\r\n    This is another race that you', mimetype='text/plain', start_char_idx=111912, end_char_idx=112800, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.5004715),
#  NodeWithScore(node=TextNode(id_='c3b68aba-04ec-4298-8e26-6a4e7913485e', embedding=None, metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='data/pg10763.txt', node_type='4', metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, hash='acd70f912398389c2056c38e808cc377391a25060d0a446a654957a3859d2be5'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='f2419b20-4d19-4638-9b55-28becd4c396b', node_type='1', metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, hash='6abc4855d54a8ac3b6352f59ff8711e22fecb0cbe75c62e59b489f1d5addd124'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='10432105-afa3-46b3-ae4d-c280713ea3c3', node_type='1', metadata={}, hash='67e46b95c07d7f9c0a26dfda69dfabcc10aa00d97661ff1ed2d2ce0a7d7de54c')}, metadata_template='{key}: {value}', metadata_separator='\n', text='_Anonymous._\r\n\r\n\r\n\r\n\r\nTHE DISAPPOINTED\r\n\r\n\r\nThose who have striven nobly and failed deserve sympathy. Sometimes they\r\ndeserve also praise unreserved, in that they have refused to do\r\nsomething ignoble which would have led to what the world calls success.\r\nThey have lived the idea which Macbeth merely proclaimed:\r\n\r\n  "I dare do all that may become a man;\r\n  Who dares do more is none."\r\n\r\n\r\n  There are songs enough for the hero\r\n    Who dwells on the heights of fame;\r\n  I sing of the disappointed--\r\n    For those who have missed their aim.\r\n\r\n  I sing with a tearful cadence\r\n    For one who stands in the dark,\r\n  And knows that his last, best arrow\r\n    Has bounded back from the mark.\r\n\r\n  I sing for the breathless runner,\r\n    The eager, anxious soul,\r\n  Who falls with his strength exhausted.\r\n    Almost in sight of the goal;\r\n\r\n  For the hearts that break in silence,\r\n    With a sorrow all unknown,\r\n  For those who need companions,\r\n    Yet walk their ways alone.\r\n\r\n  There are songs enough for the lovers\r\n    Who share love\'s tender pain,\r\n  I sing for the one whose passion\r\n    Is given all in vain.\r\n\r\n  For those whose spirit comrades\r\n    Have missed them on their way,\r\n  I sing, with a heart o\'erflowing,\r\n    This minor strain to-day.\r\n\r\n  And I know the Solar system\r\n    Must somewhere keep in space\r\n  A prize for that spent runner\r\n    Who barely lost the race.\r\n\r\n  For the plan would be imperfect\r\n    Unless it held some sphere\r\n  That paid for the toil and talent\r\n    And love that are wasted here.\r\n\r\n\r\n_Ella Wheeler Wilcox._\r\n\r\nFrom "Picked Poems."\r\n\r\n\r\n\r\n\r\nLET ME LIVE OUT MY YEARS\r\n\r\n\r\nWe speak of the comforts and ease of old age, but our noblest selves do\r\nnot really desire them. We want to do more than exist. We want to be\r\nalive to the very last.\r\n\r\n\r\n  Let me live out my years in heat of blood!\r\n  Let me die drunken with the dreamer\'s wine!\r\n  Let me not see this soul-house built of mud\r\n  Go toppling to the dust--a vacant shrine!\r\n\r\n  Let me go quickly like a candle light\r\n  Snuffed out just at the heyday of its glow!\r\n  Give me high noon--and let it then be night!\r\n      Thus would I go.\r\n\r\n  And grant that when I face the grisly Thing,\r\n  My song may triumph down the gray Perhaps!\r\n  Let me be as a tuneswept fiddlestring\r\n  T ...
#  NodeWithScore(node=TextNode(id_='28bbd5d5-d574-4caf-8192-342422422e1d', embedding=None, metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='data/pg10763.txt', node_type='4', metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, hash='acd70f912398389c2056c38e808cc377391a25060d0a446a654957a3859d2be5'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='ff6768d5-e5fe-481d-874b-6bc1cfc164bd', node_type='1', metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, hash='7e7c305a96da1af23803de26e86bcc8594774c1e6551d127a9b37290253ca1a8'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='4b09423f-05c4-4e66-a41f-afaf675e631d', node_type='1', metadata={}, hash='39be01092137de42539779de59df85974013a80577b408bf726ed3d32be03ed6')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Laugh like a boy at splendors that have sped,\r\n    To vanished joys be blind and deaf and dumb;\r\n  My judgments seal the dead past with its dead,\r\n    But never bind a moment yet to come.\r\n\r\n  Though deep in mire, wring not your hands and weep;\r\n    I lend my arm to all who say "I can!"\r\n  No shame-faced outcast ever sank so deep,\r\n    But yet might rise and be again a man!\r\n\r\n  Dost thou behold thy lost youth all aghast?\r\n    Dost reel from righteous Retribution\'s blow?\r\n  Then turn from blotted archives of the past,\r\n    And find the future\'s pages white as snow.\r\n\r\n  Art thou a mourner? Rouse thee from thy spell;\r\n    Art thou a sinner? Sins may be forgiven;\r\n  Each morning gives thee wings to flee from hell,\r\n    Each night a star to guide thy feet to heaven.\r\n\r\n\r\n_Walter Malone._\r\n\r\n\r\n\r\n\r\nOPPORTUNITY\r\n\r\n\r\nIn this poem yet another view of opportunity is presented. The recreant\r\nor the dreamer complains that he has no real chance. He would succeed,\r\nhe says, if he had but the implements of success--money, influence,\r\nsocial prestige, and the like. But success lies far less in implements\r\nthan in the use we make of them. What one man throws away as useless,\r\nanother man seizes as the best means of victory at hand. For every one\r\nof us the materials for achievement are sufficient. The spirit that\r\nprompts us is what ultimately counts.\r\n\r\n\r\n  This I beheld, or dreamed it in a dream:--\r\n  There spread a cloud of dust along a plain;\r\n  And underneath the cloud, or in it, raged\r\n  A furious battle, and men yelled, and swords\r\n  Shocked upon swords and shields. A prince\'s banner\r\n  Wavered, then staggered backward, hemmed by foes.\r\n  A craven hung along the battle\'s edge,\r\n  And thought, "Had I a sword of keener steel--\r\n  That blue blade that the king\'s son bears,--but this\r\n  Blunt thing--!" he snapt and flung it from his hand,\r\n  And lowering crept away and left the field.\r\n  Then came the king\'s son, wounded, sore bestead,\r\n  And weaponless, and saw the broken sword,\r\n  Hilt-buried in the dry and trodden sand,\r\n  And ran and snatched it, and with battle-shout\r\n  Lifted afresh he hewed his enemy down,\r\n  And saved a great cause that heroic day.\r\n\r\n\r\n_Edward Rowland Sill._\r\n\r\nFrom "Poems."\r\n\r\n\r\n\r\n[Illustration: JAMES WHITCOMB RILEY]\r\n\r\n\r\n\r\n\r\nMY PHILOSOPHY\r\n\r\n\r\nThough dog ...
#  NodeWithScore(node=TextNode(id_='a2af6f94-90dc-4226-9adb-9c96c22c0bc2', embedding=None, metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='data/pg10763.txt', node_type='4', metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, hash='acd70f912398389c2056c38e808cc377391a25060d0a446a654957a3859d2be5'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='a4e7c244-280a-4eee-92eb-6dae7256e084', node_type='1', metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, hash='f97b408982604f198370c7c335e4732ef26e21e987a97c3487653f426ee8c32b'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='5bc7f180-5daf-49fb-a019-b24e4ac70d2d', node_type='1', metadata={}, hash='814ae154736e305dee17e52f0cf348ee0b558b250660d5fce1b181ea6dd6cfbc')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Gates_\r\n\r\n\r\n\r\n\r\n\r\nIT CAN BE DONE\r\n\r\n\r\n\r\n\r\nBE THE BEST OF WHATEVER YOU ARE\r\n\r\n\r\nWe all dream of great deeds and high positions, away from the pettiness\r\nand humdrum of ordinary life. Yet success is not occupying a lofty place\r\nor doing conspicuous work; it is being the best that is in you. Rattling\r\naround in too big a job is much worse than filling a small one to\r\noverflowing. Dream, aspire by all means; but do not ruin the life you\r\nmust lead by dreaming pipe-dreams of the one you would like to lead.\r\nMake the most of what you have and are. Perhaps your trivial, immediate\r\ntask is your one sure way of proving your mettle. Do the thing near at\r\nhand, and great things will come to your hand to be done.\r\n\r\n\r\n  If you can\'t be a pine on the top of the hill\r\n    Be a scrub in the valley--but be\r\n  The best little scrub by the side of the rill;\r\n    Be a bush if you can\'t be a tree.\r\n\r\n  If you can\'t be a bush be a bit of the grass,\r\n    And some highway some happier make;\r\n  If you can\'t be a muskie then just be a bass--\r\n    But the liveliest bass in the lake!\r\n\r\n  We can\'t all be captains, we\'ve got to be crew,\r\n    There\'s something for all of us here.\r\n  There\'s big work to do and there\'s lesser to do,\r\n    And the task we must do is the near.\r\n\r\n  If you can\'t be a highway then just be a trail,\r\n    If you can\'t be the sun be a star;\r\n  It isn\'t by size that you win or you fail--\r\n    Be the best of whatever you are!\r\n\r\n\r\n_Douglas Malloch._\r\n\r\n\r\n\r\n\r\nTHE HOUSE BY THE SIDE OF THE ROAD\r\n\r\n\r\nThis poem has as its keynote friendship and sympathy for other people.\r\nIt is a paradox of life that by hoarding love and happiness we lose\r\nthem, and that only by giving them away can we keep them for ourselves.\r\nThe more we share, the more we possess. We of course find in other\r\npeople weaknesses and sins, but our best means of curing these are\r\nthrough a wise and sympathetic understanding.\r\n\r\n\r\n  Let me live in a house by the side of the road,\r\n    Where the race of men go by--\r\n  The men who are good and the men who are bad,\r\n    As good and as bad as I.\r\n  I would not sit in the scorner\'s seat,\r\n    Or hurl the cynic\'s ban;--\r\n  Let me live in a house by the side of the road\r\n    And be a friend to man.\r\n\r\n  I see from my house by the side of the road,\r\n    By the side of ...
#  NodeWithScore(node=TextNode(id_='bc0cac20-48ec-4e29-b76a-9ab42988d317', embedding=None, metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='data/pg10763.txt', node_type='4', metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, hash='acd70f912398389c2056c38e808cc377391a25060d0a446a654957a3859d2be5'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='82989f12-ab5b-44b0-8813-da402e9596d4', node_type='1', metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, hash='89bd5559d4cf9365c4cf25adfedb7d0ac85695f6ec983d3a0c5219793238ebd1'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='5709e4eb-95fd-4a84-adc2-e17f8a4d2a4e', node_type='1', metadata={}, hash='2c0c3e340e7835a21b8e3c27343139b5d9abf1ad51b51eb6824738806071dae4')}, metadata_template='{key}: {value}', metadata_separator='\n', text='UNSUBDUED\r\n\r\n\r\n"An artist\'s career," said Whistler, "always begins to-morrow." So does\r\nthe career of any man of courage and imagination. The Eden of such a man\r\ndoes not lie in yesterday. If he has done well, he forgets his\r\nachievements and dreams of the big deeds ahead. If he has been thwarted,\r\nhe forgets his failures and looks forward to vast, sure successes. If\r\nfate itself opposes him, he defies it. Farragut\'s fleet was forcing an\r\nentrance into Mobile Bay. One of the vessels struck something, a\r\nterrific explosion followed, the vessel went down. "Torpedoes, sir."\r\nThey scanned the face of the commander-in-chief. But Farragut did not\r\nhesitate. "Damn the torpedoes," said he. "Go ahead."\r\n\r\n\r\n  I have hoped, I have planned, I have striven,\r\n    To the will I have added the deed;\r\n  The best that was in me I\'ve given,\r\n    I have prayed, but the gods would not heed.\r\n\r\n  I have dared and reached only disaster,\r\n    I have battled and broken my lance;\r\n  I am bruised by a pitiless master\r\n    That the weak and the timid call Chance.\r\n\r\n  I am old, I am bent, I am cheated\r\n    Of all that Youth urged me to win;\r\n  But name me not with the defeated,\r\n    To-morrow again, I begin.\r\n\r\n\r\n_S.E. Kiser._\r\n\r\nFrom "Poems That Have Helped Me."\r\n\r\n\r\n\r\n\r\nWORK\r\n\r\n"A SONG OF TRIUMPH"\r\n\r\n\r\nWhen Captain John Smith was made the leader of the colonists at\r\nJamestown, Va., he discouraged the get-rich-quick seekers of gold by\r\nannouncing flatly, "He who will not work shall not eat." This rule made\r\nof Jamestown the first permanent English settlement in the New World.\r\nBut work does more than lead to material success. It gives an outlet\r\nfrom sorrow, restrains wild desires, ripens and refines character,\r\nenables human beings to cooperate with God, and when well done, brings\r\nto life its consummate satisfaction. Every man is a Prince of\r\nPossibilities, but by work alone can he come into his Kingship.\r\n\r\n\r\n  Work!\r\n  Thank God for the might of it,\r\n  The ardor, the urge, the delight of it--\r\n  Work that springs from the heart\'s desire,\r\n  Setting the brain and the soul on fire--\r\n  Oh, what is so good as the heat of it,\r\n  And what is so glad as the beat of it,\r\n  And what is so kind as the stern command,\r\n  Challenging brain and heart and hand?\r\n\r\n  Work!\r\n  Thank God for the pride of it,\r\n  For the b ...
#  NodeWithScore(node=TextNode(id_='09e8694b-efe7-4153-a9a3-27e27501221b', embedding=None, metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='data/pg10763.txt', node_type='4', metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, hash='acd70f912398389c2056c38e808cc377391a25060d0a446a654957a3859d2be5'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='b13b53ce-9e35-4cfa-b13d-0ba4b70e314a', node_type='1', metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, hash='2ddfbade20a6f1194e9071580430c1c5157f75e4e557be4224beb163b153a9a2'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='965a62f3-6bb7-48eb-9a90-ee5e05c22264', node_type='1', metadata={}, hash='5cd134b170353e3259698ec093c15d87c593d95da3fa8ec097036520e9d0fc3b')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Say! Let\'s not take it so sorely to heart!\r\n  Hates may be friendships just drifted apart,\r\n  Failure be genius not quite understood,\r\n  Say! Let\'s get closer to somebody\'s side,\r\n  See what his dreams are and learn how he tried,\r\n  See if our scoldings won\'t give way to praise\r\n  One of these days.\r\n\r\n  Say! Let\'s not wither! Let\'s branch out and rise\r\n  Out of the byways and nearer the skies.\r\n  Let\'s spread some shade that\'s refreshing and deep\r\n  Where some tired traveler may lie down and sleep.\r\n  Say! Let\'s not tarry! Let\'s do it right now;\r\n  So much to do if we just find out how!\r\n  We may not be here to help folks or praise\r\n  One of these days.\r\n\r\n\r\n_James W. Foley._\r\n\r\nFrom "The Voices of Song."\r\n\r\n\r\n\r\n[Illustration: JAMES WILLIAM FOLEY]\r\n\r\n\r\n\r\n\r\nGOD\r\n\r\n\r\nWe often think people shallow, think them incapable of anything serious\r\nor profound, because their work is humdrum and their speech trivial.\r\nSuch a judgment is unfair, since that part of our own life which shows\r\nitself to others is superficial likewise, though we are conscious that\r\nwithin us is much that it does not reveal.\r\n\r\n\r\n  I think about God.\r\n    Yet I talk of small matters.\r\n  Now isn\'t it odd\r\n    How my idle tongue chatters!\r\n  Of quarrelsome neighbors,\r\n    Fine weather and rain,\r\n  Indifferent labors,\r\n    Indifferent pain,\r\n  Some trivial style\r\n    Fashion shifts with a nod.\r\n  And yet all the while\r\n    I am thinking of God.\r\n\r\n\r\n_Gamaliel Bradford._\r\n\r\nFrom "Shadow Verses."\r\n\r\n\r\n\r\n\r\nMY TRIUMPH\r\n\r\n\r\nThe poet, looking back upon the hopes he has cherished, perceives that\r\nhe has fallen far short of achieving them. The songs he has sung are\r\nless sweet than those he has dreamed of singing; the wishes he has\r\nwrought into facts are less noble than those that are yet unfulfilled.\r\nBut he looks forward to the time when all that he desires for humankind\r\nshall yet come to pass. The praise will not be his; it will belong to\r\nothers. Still, he does not envy those who are destined to succeed where\r\nhe failed. Rather does he rejoice that through them his hopes for the\r\nrace will be realized. And he is happy that by longing for just such a\r\ntriumph he shares in it--he makes it _his_ triumph.\r\n\r\n\r\n  Let the thick curtain fall;\r\n  I better know than all\r\n  How little I have gained,\r\n  ...
#  NodeWithScore(node=TextNode(id_='b8b312b0-04a3-457e-b3f5-0035091e43c9', embedding=None, metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='data/pg10763.txt', node_type='4', metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, hash='acd70f912398389c2056c38e808cc377391a25060d0a446a654957a3859d2be5'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='db94efed-c10a-4793-b0cb-8179e5626d9f', node_type='1', metadata={'file_path': 'data/pg10763.txt', 'file_name': 'pg10763.txt', 'file_type': 'text/plain', 'file_size': 405150, 'creation_date': '2025-11-02', 'last_modified_date': '2025-11-02'}, hash='de5b55af6e1b13cba532931894de815300ef8685a2a0a01bbe438f348441e1ee'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='c8b15909-9411-4179-8b82-bc673795661c', node_type='1', metadata={}, hash='73d2d2e352e20b9c416131bb3ef7c0e378d297f89be334936b68156897555ba5')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Astronomers\r\ntell us that in space are countless worlds, many of them doubtless\r\ninhabited--perhaps by creatures of a lower type than we, perhaps by\r\ncreatures of a higher. The magnitude of these changes and of these\r\nworlds makes the imagination reel. But on one thing we can rely--the\r\ngreatness of the human soul. On one thing we can confidently build--the\r\nmen whose spirit is lofty, divine.\r\n\r\n\r\n  For tho\' the Giant Ages heave the hill\r\n  And break the shore, and evermore\r\n  Make and break, and work their will;\r\n  Tho\' world on world in myriad myriads roll\r\n  Round us, each with different powers,\r\n  And other forms of life than ours,\r\n  What know we greater than the soul?\r\n  On God and Godlike men we build our trust.\r\n\r\n\r\n  _Alfred Tennyson_.\r\n\r\n\r\n\r\n\r\nHEINELET\r\n\r\n\r\nWhat sheer perseverance can accomplish, even in matters of the heart, is\r\nrevealed in this little poem written in Heine\'s mood of mingled\r\nseriousness and gayety.\r\n\r\n\r\n  He asked if she ever could love him.\r\n    She answered him, no, on the spot.\r\n  He asked if she ever could love him.\r\n    She assured him again she could not.\r\n\r\n  He asked if she ever could love him.\r\n    She laughed till his blushes he hid.\r\n  He asked if she ever could love him.\r\n    By God, she admitted she did.\r\n\r\n\r\n_Gamaliel Bradford_.\r\n\r\nFrom "Shadow Verses."\r\n\r\n\r\n\r\n\r\nSTAND FORTH!\r\n\r\n\r\nThe human spirit can triumph over difficulties, as flowers bloom along\r\nthe edge of the Alpine snow.\r\n\r\n\r\n  Stand forth, my soul, and grip thy woe,\r\n  Buckle the sword and face thy foe.\r\n  What right hast thou to be afraid\r\n  When all the universe will aid?\r\n  Ten thousand rally to thy name,\r\n  Horses and chariots of flame.\r\n  Do others fear? Do others fail?\r\n  _My soul must grapple and prevail_.\r\n  My soul must scale the mountainside\r\n  And with the conquering army ride--\r\n  Stand forth, my soul!\r\n\r\n  Stand forth, my soul, and take command.\r\n  \'Tis I, thy master, bid thee stand.\r\n  Claim thou thy ground and thrust thy foe,\r\n  Plead not thine enemy should go.\r\n  Let others cringe! My soul is free,\r\n  No hostile host can conquer me.\r\n  There lives no circumstance so great\r\n  Can make me yield, or doubt my fate.\r\n  My soul must know what kings have known.\r\n  Must reach and claim its rightful throne--\r\n  Stand forth, my soul!\r\n\r\n  I ask n ...

# %%
print(retrieved_nodes[0].get_text())
# Out:
# the right way."
#
#   Then shall I see it not too great, nor small
#     To suit my spirit and to prove my powers;
#     Then shall I cheerful greet the laboring hours,
#   And cheerful turn, when the long shadows fall
#   At eventide, to play and love and rest,
#   Because I know for me my work is best.
#
#
# _Henry Van Dyke._
#
# From "Collected Poems."
#
#
#
#
# START WHERE YOU STAND
#
#
# When a man who had been in the penitentiary applied to Henry Ford for
# employment, he started to tell Mr. Ford his story. "Never mind," said
# Mr. Ford, "I don't care about the past. Start where you stand!"--Author's
# note.
#
#
#   Start where you stand and never mind the past,
#     The past won't help you in beginning new,
#   If you have left it all behind at last
#     Why, that's enough, you're done with it, you're through;
#   This is another chapter in the book,
#     This is another race that you

# %%
print(retrieved_nodes[0].get_score())
# Out:
# 0.5004715

# %% [markdown]
# The ingestion pipeline allows for saves the cache and docstore to a default folder `(./pipeline_storage)`.
#
# When running the pipeline, it reuses the cache, skips duplicate documents in the docstore.

# %%
pipeline.persist('./pipeline_storage')
