# %%
# %%capture
# !pip install llama-index==0.10.37 llama-index-embeddings-cohere qdrant-client==1.9.1 llama-index-vector-stores-qdrant==0.2.8 llama-index-llms-cohere==0.2.0 llama-index-llms-ollama

# %%
import os
import sys
from getpass import getpass
import nest_asyncio

from IPython.display import Markdown, display

from dotenv import load_dotenv

nest_asyncio.apply()

load_dotenv()

sys.path.append('../helpers')

from utils import setup_llm, setup_embed_model, setup_vector_store

# %%
CO_API_KEY = os.environ['CO_API_KEY'] or getpass("Enter your Cohere API key: ")

# %%
OPENAI_API_KEY = os.environ['OPENAI_API_KEY'] or getpass("Enter your OpenAI API key: ")

# %%
QDRANT_URL = os.environ['QDRANT_URL'] or getpass("Enter your Qdrant URL:")

# %%
QDRANT_API_KEY = os.environ['QDRANT_API_KEY'] or  getpass("Enter your Qdrant API Key:")

# %%
from llama_index.core.settings import Settings
from utils import setup_llm, setup_embed_model, setup_vector_store

COLLECTION_NAME = "words-of-the-senpai-naive"

# Use Ollama instead of Cohere for consistency
setup_llm(
    provider="ollama", 
    model="", 
    api_key=""
    )

setup_embed_model(provider="cohere", api_key=CO_API_KEY)

# Debug: Verify models are set correctly
print(f"LLM type: {type(Settings.llm)}")
print(f"Embedding model type: {type(Settings.embed_model)}")

vector_store = setup_vector_store(QDRANT_URL, QDRANT_API_KEY, COLLECTION_NAME)
# Out:
# LLM type: <class 'llama_index.llms.ollama.base.Ollama'>
# Embedding model type: <class 'llama_index.embeddings.cohere.base.CohereEmbedding'>

# %%
Settings.llm
# Out:
# Ollama(callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x17a1e9310>, system_prompt=None, messages_to_prompt=<function messages_to_prompt at 0x16e8bc2c0>, completion_to_prompt=<function default_completion_to_prompt at 0x175f996c0>, output_parser=None, pydantic_program_mode=<PydanticProgramMode.DEFAULT: 'default'>, query_wrapper_prompt=None, base_url='http://localhost:11434', model='qwen2.5:7b', temperature=None, context_window=8000, request_timeout=120.0, prompt_key='prompt', json_mode=False, additional_kwargs={}, is_function_calling_model=True, keep_alive=None, thinking=None)

# %%
Settings.embed_model
# Out:
# CohereEmbedding(model_name='embed-english-v3.0', embed_batch_size=10, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x17a1e9310>, num_workers=None, embeddings_cache=None, api_key='D837umjWnWmrAcfabry3it8bn3ZZs74TOLi73Zqp', base_url=None, truncate='END', input_type=None, embedding_type='float')

# %% [markdown]
# # Load Docstore

# %%
from utils import get_documents_from_docstore

documents = get_documents_from_docstore("../data/words-of-the-senpais")

# %%
documents[0].__dict__
# Out:
# {'id_': '7a6ec0a9-fc20-4eee-8665-1cef10deb231',
#  'embedding': None,
#  'metadata': {'page_number': 0,
#   'file_name': '../data/almanack_of_naval_ravikant.pdf',
#   'title': 'The Almanack of Naval Ravikant',
#   'author': 'Naval Ravikant'},
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'relationships': {},
#  'metadata_template': '{key}: {value}',
#  'metadata_separator': '\n',
#  'text_resource': MediaResource(embeddings=None, data=None, text='UNDERSTAND HOW WEALTH IS CREATED I like to think that if I lost all my money and you dropped me on a random street in any English-speaking country, within five or ten years Id be wealthy again because its just a skillset Ive developed that anyone can develop. Its not really about hard work. You can work in a restaurant eighty hours a week, and youre not going to get rich. Getting rich is about knowing what to do, who to do it with, and when to do it. It is much more about understanding than purely hard work. Yes, hard work matters, and you cant skimp on it. But it has to be directed in the right way. If you dont know yet what you should work on, the most important thing is to figure it out. You should not grind at a lot of hard work until you figure out what you should be working on. I came up with the principles in my tweetstorm (below) for myself when I was really young, around thirteen or fourteen. Ive been carrying them in my head for thirty years, and Ive been living them. Over time (sadly or fortunately), the thing I got really good at was looking at businesses and figuring out the point of maximum leverage to actually create wealth and capture some of that created wealth. This is exactly what I did my famous tweetstorm about. Of course, every one of these tweets can be extrapolated into an hours worth of conversation. The tweetstorm below is a good starting point. The tweetstorm tries to be information-dense, very concise, high-impact, and timeless. It has all the information and principles, so if you absorb these and you work hard over ten years, youll get what you want.', path=None, url=None, mimetype=None),
#  'image_resource': None,
#  'audio_resource': None,
#  'video_resource': None,
#  'text_template': '{metadata_str}\n\n{content}'}

# %% [markdown]
# # Ingest to VectorDatabase

# %%
from llama_index.core.constants import DEFAULT_CHUNK_SIZE
from llama_index.core.node_parser.text import SentenceSplitter
from llama_index.core import StorageContext
from utils import ingest

print(f"This is the chunk size: {DEFAULT_CHUNK_SIZE}")

# Fix typo: transforms not tranforms
transforms = [
    SentenceSplitter(chunk_size=DEFAULT_CHUNK_SIZE), 
    Settings.embed_model
    ]

nodes = ingest(
    transformations=transforms,
    documents=documents,
    vector_store=vector_store,
)

print(f"Processed {len(nodes)} nodes")
# Out:
# This is the chunk size: 1024
# ---------------------------------------------------------------------------
# TooManyRequestsError                      Traceback (most recent call last)
# Cell In[13], line 14
#       8 # Fix typo: transforms not tranforms
#       9 transforms = [
#      10     SentenceSplitter(chunk_size=DEFAULT_CHUNK_SIZE),
#      11     Settings.embed_model
#      12     ]
# ---> 14 nodes = ingest(
#      15     transformations=transforms,
#      16     documents=documents,
#      17     vector_store=vector_store,
#      18 )
#      20 print(f"Processed {len(nodes)} nodes")
#
# File ~/hands-on-ai-rag-using-llamaindex-3830207/03_Introduction_to_RAG/../helpers/utils.py:122, in ingest(transformations, documents, **kwargs)
#     102 """
#     103 Createsan IngestionPipeline and ingests the documents.
#     104
#    (...)    114
#     115 """
#     117 pipeline = IngestionPipeline(
#     118     transformations=transformations,
#     119     **kwargs
#     120 )
# --> 122 return pipeline.run(nodes=documents)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/core/ingestion/pipeline.py:552, in IngestionPipeline.run(self, show_progress, documents, nodes, cache_collection, in_place, store_doc_text, num_workers, **kwargs)
#     550         nodes = reduce(lambda x, y: x + y, nodes_parallel, [])  # type: ignore
#     551 else:
# --> 552     nodes = run_transformations(
#     553         nodes_to_run,
#     554         self.transformations,
#     555         show_progress=show_progress,
#     556         cache=self.cache if not self.disable_cache else None,
#     557         cache_collection=cache_collection,
#     558         in_place=in_place,
#     559         **kwargs,
#     560     )
#     562 nodes = nodes or []
#     564 if self.vector_store is not None:
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/core/ingestion/pipeline.py:98, in run_transformations(nodes, transformations, in_place, cache, cache_collection, **kwargs)
#      96         nodes = cached_nodes
#      97     else:
# ---> 98         nodes = transform(nodes, **kwargs)
#      99         cache.put(hash, nodes, collection=cache_collection)
#     100 else:
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/core/base/embeddings/base.py:594, in BaseEmbedding.__call__(self, nodes, **kwargs)
#     593 def __call__(self, nodes: Sequence[BaseNode], **kwargs: Any) -> Sequence[BaseNode]:
# --> 594     embeddings = self.get_text_embedding_batch(
#     595         [node.get_content(metadata_mode=MetadataMode.EMBED) for node in nodes],
#     596         **kwargs,
#     597     )
#     599     for node, embedding in zip(nodes, embeddings):
#     600         node.embedding = embedding
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/core/base/embeddings/base.py:473, in BaseEmbedding.get_text_embedding_batch(self, texts, show_progress, **kwargs)
#     468 with self.callback_manager.event(
#     469     CBEventType.EMBEDDING,
#     470     payload={EventPayload.SERIALIZED: self.to_dict()},
#     471 ) as event:
#     472     if not self.embeddings_cache:
# --> 473         embeddings = self._get_text_embeddings(cur_batch)
#     474     elif self.embeddings_cache is not None:
#     475         embeddings = self._get_text_embeddings_cached(cur_batch)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/embeddings/cohere/base.py:406, in CohereEmbedding._get_text_embeddings(self, texts)
#     404 def _get_text_embeddings(self, texts: List[str]) -> List[List[float]]:
#     405     """Get text embeddings."""
# --> 406     return self._embed(texts, input_type="search_document")
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/embeddings/cohere/base.py:291, in CohereEmbedding._embed(self, texts, input_type)
#     288 else:
#     289     input_type = self.input_type or input_type
# --> 291 result = client.embed(
#     292     texts=texts,
#     293     input_type=input_type,
#     294     embedding_types=[self.embedding_type],
#     295     model=self.model_name,
#     296     truncate=self.truncate,
#     297 ).embeddings
#     299 return getattr(result, self.embedding_type, None)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/cohere/v2/client.py:480, in V2Client.embed(self, model, input_type, texts, images, inputs, max_tokens, output_dimension, embedding_types, truncate, priority, request_options)
#     387 def embed(
#     388     self,
#     389     *,
#    (...)    400     request_options: typing.Optional[RequestOptions] = None,
#     401 ) -> EmbedByTypeResponse:
#     402     """
#     403     This endpoint returns text embeddings. An embedding is a list of floating point numbers that captures semantic information about the text that it represents.
#     404
#    (...)    478     )
#     479     """
# --> 480     _response = self._raw_client.embed(
#     481         model=model,
#     482         input_type=input_type,
#     483         texts=texts,
#     484         images=images,
#     485         inputs=inputs,
#     486         max_tokens=max_tokens,
#     487         output_dimension=output_dimension,
#     488         embedding_types=embedding_types,
#     489         truncate=truncate,
#     490         priority=priority,
#     491         request_options=request_options,
#     492     )
#     493     return _response.data
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/cohere/v2/raw_client.py:877, in RawV2Client.embed(self, model, input_type, texts, images, inputs, max_tokens, output_dimension, embedding_types, truncate, priority, request_options)
#     866     raise UnprocessableEntityError(
#     867         headers=dict(_response.headers),
#     868         body=typing.cast(
#    (...)    874         ),
#     875     )
#     876 if _response.status_code == 429:
# --> 877     raise TooManyRequestsError(
#     878         headers=dict(_response.headers),
#     879         body=typing.cast(
#     880             typing.Optional[typing.Any],
#     881             construct_type(
#     882                 type_=typing.Optional[typing.Any],  # type: ignore
#     883                 object_=_response.json(),
#     884             ),
#     885         ),
#     886     )
#     887 if _response.status_code == 498:
#     888     raise InvalidTokenError(
#     889         headers=dict(_response.headers),
#     890         body=typing.cast(
#    (...)    896         ),
#     897     )
#
# TooManyRequestsError: headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '837eec61c0845d9f05b281de52510868', 'x-endpoint-monthly-call-limit': '1000', 'x-trial-endpoint-call-limit': '100', 'x-trial-endpoint-call-remaining': '63', 'date': 'Thu, 06 Nov 2025 13:04:33 GMT', 'x-envoy-upstream-service-time': '11', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': 'a6354110-682f-4f89-ae69-97c34bccb43a', 'message': 'trial token rate limit exceeded, limit is 100000 tokens per minute'}

# %% [markdown]
# # Build index over vector database

# %%
from utils import create_index, create_query_engine

storage_context = StorageContext.from_defaults(
    vector_store=vector_store
    )

index = create_index(
    from_where="vector_store",
    embed_model=Settings.embed_model, 
    vector_store=vector_store, 
    storage_context=storage_context
    )

query_engine = create_query_engine(
    index=index, 
    mode="query",
    similarity_top_k=3,
    return_sources=True
    )

# %% [markdown]
# # Query Workflows (Updated from deprecated QueryPipeline)

# %%
from llama_index.core.workflow import Workflow, step, StartEvent, StopEvent
import asyncio

class QueryEvent(StartEvent):
    input: str

class ResponseEvent(StopEvent):
    result: str

class QueryWorkflow(Workflow):
    def __init__(self, query_engine, **kwargs):
        super().__init__(**kwargs)
        self.query_engine = query_engine
    
    @step
    async def run_query(self, ev: QueryEvent) -> ResponseEvent:
        response = self.query_engine.query(ev.input)
        return ResponseEvent(result=response)

# Create workflow instance
workflow = QueryWorkflow(query_engine=query_engine, verbose=True)
# Out:
# /var/folders/5p/trf91_p17bg3d0t9l5pl9kdm0000gn/T/ipykernel_42932/1967232520.py:7: UserWarning: Field name "result" in "ResponseEvent" shadows an attribute in parent "StopEvent"
#   class ResponseEvent(StopEvent):

# %% [markdown]
# # Query

# %%
async def run_workflow_query(input_text):
    response = await workflow.run(input=input_text)
    return response

response_1 = asyncio.run(run_workflow_query("What mental models, principles or philosophies are most valuable for making important life decisions and navigating an uncertain world?"))
# Out:
# Running step run_query
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[16], line 5
#       2     response = await workflow.run(input=input_text)
#       3     return response
# ----> 5 response_1 = asyncio.run(run_workflow_query("What mental models, principles or philosophies are most valuable for making important life decisions and navigating an uncertain world?"))
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/asyncio/futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/asyncio/tasks.py:306, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     304         result = coro.send(None)
#     305     else:
# --> 306         result = coro.throw(exc)
#     307 except StopIteration as exc:
#     308     if self._must_cancel:
#     309         # Task is cancelled right before coro stops.
#
# Cell In[16], line 2, in run_workflow_query(input_text)
#       1 async def run_workflow_query(input_text):
# ----> 2     response = await workflow.run(input=input_text)
#       3     return response
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/asyncio/futures.py:286, in Future.__await__(self)
#     284 if not self.done():
#     285     self._asyncio_future_blocking = True
# --> 286     yield self  # This tells Task to wait for completion.
#     287 if not self.done():
#     288     raise RuntimeError("await wasn't used with future")
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/asyncio/tasks.py:375, in Task.__wakeup(self, future)
#     373 def __wakeup(self, future):
#     374     try:
# --> 375         future.result()
#     376     except BaseException as exc:
#     377         # This may also be a cancellation.
#     378         self.__step(exc)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/asyncio/futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/workflows/workflow.py:439, in Workflow.run.<locals>._run_workflow(ctx)
#     435 if exception_raised:
#     436     # cancel the stream
#     437     ctx.write_event_to_stream(StopEvent())
# --> 439     raise exception_raised
#     441 if not we_done:
#     442     # cancel the stream
#     443     ctx.write_event_to_stream(StopEvent())
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/asyncio/tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     300 try:
#     301     if exc is None:
#     302         # We use the `send` method directly, because coroutines
#     303         # don't have `__iter__` and `__next__` methods.
# --> 304         result = coro.send(None)
#     305     else:
#     306         result = coro.throw(exc)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/workflows/context/context.py:822, in Context._step_worker(self, name, step, config, verbose, run_id, worker_id, resource_manager)
#     813 self.write_event_to_stream(
#     814     StepStateChanged(
#     815         name=name,
#    (...)    819     )
#     820 )
#     821 try:
# --> 822     new_ev = await instrumented_step(**kwargs)
#     823     kwargs.clear()
#     824     break  # exit the retrying loop
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:386, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     378 self.span_enter(
#     379     id_=id_,
#     380     bound_args=bound_args,
#    (...)    383     tags=tags,
#     384 )
#     385 try:
# --> 386     result = await func(*args, **kwargs)
#     387 except BaseException as e:
#     388     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# Cell In[15], line 17, in QueryWorkflow.run_query(self, ev)
#      15 @step
#      16 async def run_query(self, ev: QueryEvent) -> ResponseEvent:
# ---> 17     response = self.query_engine.query(ev.input)
#      18     return ResponseEvent(result=response)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/core/base/base_query_engine.py:44, in BaseQueryEngine.query(self, str_or_query_bundle)
#      42     if isinstance(str_or_query_bundle, str):
#      43         str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 44     query_result = self._query(str_or_query_bundle)
#      45 dispatcher.event(
#      46     QueryEndEvent(query=str_or_query_bundle, response=query_result)
#      47 )
#      48 return query_result
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/core/query_engine/retriever_query_engine.py:196, in RetrieverQueryEngine._query(self, query_bundle)
#     192 """Answer a query."""
#     193 with self.callback_manager.event(
#     194     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     195 ) as query_event:
# --> 196     nodes = self.retrieve(query_bundle)
#     197     response = self._response_synthesizer.synthesize(
#     198         query=query_bundle,
#     199         nodes=nodes,
#     200     )
#     201     query_event.on_end(payload={EventPayload.RESPONSE: response})
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/core/query_engine/retriever_query_engine.py:149, in RetrieverQueryEngine.retrieve(self, query_bundle)
#     148 def retrieve(self, query_bundle: QueryBundle) -> List[NodeWithScore]:
# --> 149     nodes = self._retriever.retrieve(query_bundle)
#     150     return self._apply_node_postprocessors(nodes, query_bundle=query_bundle)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/core/base/base_retriever.py:210, in BaseRetriever.retrieve(self, str_or_query_bundle)
#     205 with self.callback_manager.as_trace("query"):
#     206     with self.callback_manager.event(
#     207         CBEventType.RETRIEVE,
#     208         payload={EventPayload.QUERY_STR: query_bundle.query_str},
#     209     ) as retrieve_event:
# --> 210         nodes = self._retrieve(query_bundle)
#     211         nodes = self._handle_recursive_retrieval(query_bundle, nodes)
#     212         retrieve_event.on_end(
#     213             payload={EventPayload.NODES: nodes},
#     214         )
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/core/indices/vector_store/retrievers/retriever.py:104, in VectorIndexRetriever._retrieve(self, query_bundle)
#      98     if query_bundle.embedding is None and len(query_bundle.embedding_strs) > 0:
#      99         query_bundle.embedding = (
#     100             self._embed_model.get_agg_embedding_from_queries(
#     101                 query_bundle.embedding_strs
#     102             )
#     103         )
# --> 104 return self._get_nodes_with_embeddings(query_bundle)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/core/indices/vector_store/retrievers/retriever.py:220, in VectorIndexRetriever._get_nodes_with_embeddings(self, query_bundle_with_embeddings)
#     216 def _get_nodes_with_embeddings(
#     217     self, query_bundle_with_embeddings: QueryBundle
#     218 ) -> List[NodeWithScore]:
#     219     query = self._build_vector_store_query(query_bundle_with_embeddings)
# --> 220     query_result = self._vector_store.query(query, **self._kwargs)
#     222     nodes_to_fetch = self._determine_nodes_to_fetch(query_result)
#     223     if nodes_to_fetch:
#     224         # Fetch any missing nodes from the docstore and insert them into the query result
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/llama_index/vector_stores/qdrant/base.py:1153, in QdrantVectorStore.query(self, query, **kwargs)
#    1150     return self.parse_to_query_result(response[0])
#    1151 else:
#    1152     # Regular non-hybrid search
# -> 1153     response = self._client.search(
#    1154         collection_name=self.collection_name,
#    1155         query_vector=(
#    1156             rest.NamedVector(
#    1157                 name=self.dense_vector_name,
#    1158                 vector=query_embedding,
#    1159             )
#    1160         ),
#    1161         limit=query.similarity_top_k,
#    1162         query_filter=query_filter,
#    1163         shard_key_selector=shard_key,
#    1164     )
#    1165     return self.parse_to_query_result(response)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/qdrant_client/qdrant_client.py:376, in QdrantClient.search(self, collection_name, query_vector, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, append_payload, consistency, shard_key_selector, timeout, **kwargs)
#     369 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
#     370 warnings.warn(
#     371     "`search` method is deprecated and will be removed in the future."
#     372     " Use `query_points` instead.",
#     373     DeprecationWarning,
#     374     stacklevel=2,
#     375 )
# --> 376 return self._client.search(
#     377     collection_name=collection_name,
#     378     query_vector=query_vector,
#     379     query_filter=query_filter,
#     380     search_params=search_params,
#     381     limit=limit,
#     382     offset=offset,
#     383     with_payload=with_payload,
#     384     with_vectors=with_vectors,
#     385     score_threshold=score_threshold,
#     386     append_payload=append_payload,
#     387     consistency=consistency,
#     388     shard_key_selector=shard_key_selector,
#     389     timeout=timeout,
#     390     **kwargs,
#     391 )
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/qdrant_client/qdrant_remote.py:523, in QdrantRemote.search(self, collection_name, query_vector, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, append_payload, consistency, shard_key_selector, timeout, **kwargs)
#     520 if isinstance(with_payload, grpc.WithPayloadSelector):
#     521     with_payload = GrpcToRest.convert_with_payload_selector(with_payload)
# --> 523 search_result = self.http.search_api.search_points(
#     524     collection_name=collection_name,
#     525     consistency=consistency,
#     526     timeout=timeout,
#     527     search_request=models.SearchRequest(
#     528         vector=query_vector,
#     529         filter=query_filter,
#     530         limit=limit,
#     531         offset=offset,
#     532         params=search_params,
#     533         with_vector=with_vectors,
#     534         with_payload=with_payload,
#     535         score_threshold=score_threshold,
#     536         shard_key=shard_key_selector,
#     537     ),
#     538 )
#     539 result: Optional[list[types.ScoredPoint]] = search_result.result
#     540 assert result is not None, "Search returned None"
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/qdrant_client/http/api/search_api.py:936, in SyncSearchApi.search_points(self, collection_name, consistency, timeout, search_request)
#     926 def search_points(
#     927     self,
#     928     collection_name: str,
#    (...)    931     search_request: m.SearchRequest = None,
#     932 ) -> m.InlineResponse20017:
#     933     """
#     934     Retrieve closest points based on vector similarity and given filtering conditions
#     935     """
# --> 936     return self._build_for_search_points(
#     937         collection_name=collection_name,
#     938         consistency=consistency,
#     939         timeout=timeout,
#     940         search_request=search_request,
#     941     )
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/qdrant_client/http/api/search_api.py:487, in _SearchApi._build_for_search_points(self, collection_name, consistency, timeout, search_request)
#     485 if "Content-Type" not in headers:
#     486     headers["Content-Type"] = "application/json"
# --> 487 return self.api_client.request(
#     488     type_=m.InlineResponse20017,
#     489     method="POST",
#     490     url="/collections/{collection_name}/points/search",
#     491     headers=headers if headers else None,
#     492     path_params=path_params,
#     493     params=query_params,
#     494     content=body,
#     495 )
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/qdrant_client/http/api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File /opt/anaconda3/envs/lil_llama_index/lib/python3.13/site-packages/qdrant_client/http/api_client.py:130, in ApiClient.send(self, request, type_)
#     128     except ValidationError as e:
#     129         raise ResponseHandlingException(e)
# --> 130 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 404 (Not Found)
# Raw response content:
# b'{"status":{"error":"Not found: Collection `words-of-the-senpai-naive` doesn\'t exist!"},"time":2.74e-6}'

# %%
print(response_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(response_1)
#
# NameError: name 'response_1' is not defined

# %%
# Access source nodes from the response
if hasattr(response_1, 'source_nodes') and response_1.source_nodes:
    print("Source node metadata:")
    print(response_1.source_nodes[0].__dict__)
else:
    print("No source nodes available")

# %%
response_2 = asyncio.run(run_workflow_query("What is the essence of a life well-lived, and what are the key components of a good life that everyone should strive for?"))
print(response_2)

# %%
response_3 = asyncio.run(run_workflow_query("What role does luck play in achieving outsized success and wealth creation? Is capitalizing on luck a skill that can be cultivated?"))
print(response_3)

# %%
response_4 = asyncio.run(run_workflow_query("What are some commonalities between Naval Ravikant and Nassim Taleb's thinking on luck?"))
print(response_4)
